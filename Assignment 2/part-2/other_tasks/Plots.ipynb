2.3356867980790597 ,
2.0840476822124465 ,
1.8333609838247256 ,
1.6482972691871929 ,
1.4827762965456124 ,
1.3206361304291718 ,
1.1661752472267253 ,
1.0211080314037275 ,
0.8795641534857594 ,
0.5483667381825086 ,
0.4322522783359375 ,
0.36847664164279337 ,
0.313154075621938 ,
0.2598816654364384 ,
0.14339217345399646 ,
0.12205992225627682 ,
0.10383509148560677 ,
0.08828858225056635 ,
0.07504199182581672 ,
0.0637649033077814 ,
0.05417084953678852 ,
0.04601276373198715 ,
0.03907838556388299 ,
0.03318588560765434 ,
0.02817984145296748 ,
0.023927620697286045 ,
0.02031617977472777 ,
0.017249261587618747 ,
0.014644961437745962 ,
0.012433624937813192 ,
0.010556040293391078 ,
0.008961888626661363 ,
0.007608418642977455 ,
0.006459315177099967 ,
0.005483734554005082 ,
0.004655483006388295 ,
0.0039523174734874544 ,
0.003355350900474008 ,
0.0028485466454988284 ,
0.002418288788820888 ,
0.002053017043554206 ,
0.0017429166166706977 ,
0.001479654788930418 ,
0.0012561572020217682 ,
0.001066417883563986 ,
0.0009053379332613076
]
Errors_part2_3 = [
    35.00000000000001 ,
4.875 ,
0.8656250000000014 ,
0.1831046875000002 ,
0.04535042968749892 ,
0.011305676757814354 ,
0.002817000491329935 ,
0.0006946459906238545 
]
iterations = [58, 43, 27, 20, 15, 12, 9, 7, 6]
choice = [round(0.1 * i, 1) for i in range(9, 0, -1)]

xs = range(9)
print(iterations, choice)

x_1 = choice
y_1 = iterations
plt.figure(figsize=(8, 5))
# Display plot with x & y
plt.plot(xs, y_1)
plt.xticks(xs, choice)
# Add a title
plt.title('Gamma vs Number of Iterations', fontweight='bold', fontsize=15)
# Add an X & Y Label
plt.xlabel('Gamma', fontweight='bold', fontsize=12)
plt.ylabel('Number of Iterations', fontweight='bold', fontsize=12)
# Out:
# [58, 43, 27, 20, 15, 12, 9, 7, 6] [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]
# Text(0, 0.5, 'Number of Iterations')

# %%
import json
path = './VI_iteration_data.json'
with open(path) as file:
    data = json.load(file)
# print(data)

# %%
# state => value
V = data['V']
# state => best_action
best_action = data['best_action']
# state => list of [p, next_state, next_state_value]
best_action_result = data['best_action_result']
# state => all possible actions in the same format
action_results = data['action_results']
print(action_results)
# Out:
# {'[0, 0, 0, 0, 25]': {'STAY': [[0.8, [0, 0, 0, 0, 25], -90.41090877403225], [0.2, [0, 0, 0, 1, 25], -108.60277285244862], [0.0, [2, 0, 0, 0, 25], -46.681285076476925], [0.0, [2, 0, 0, 1, 25], -105.32611624478994]], 'RIGHT': [[0.8, [4, 0, 0, 0, 25], -68.35160634559614], [0.2, [4, 0, 0, 1, 25], -129.05200128684857], [0.0, [2, 0, 0, 0, 25], -46.681285076476925], [0.0, [2, 0, 0, 1, 25], -105.32611624478994]]}, '[0, 0, 0, 0, 50]': {'STAY': [[0.8, [0, 0, 0, 0, 50], -133.22991183850093], [0.2, [0, 0, 0, 1, 50], -152.9424973766137], [0.0, [2, 0, 0, 0, 50], -76.55280846631001], [0.0, [2, 0, 0, 1, 50], -172.7248814350316]], 'RIGHT': [[0.8, [4, 0, 0, 0, 50], -105.6910105828875], [0.2, [4, 0, 0, 1, 50], -194.00488900703684], [0.0, [2, 0, 0, 0, 50], -76.55280846631001], [0.0, [2, 0, 0, 1, 50], -172.7248814350316]]}, '[0, 0, 0, 0, 75]': {'STAY': [[0.8, [0, 0, 0, 0, 75], -201.0630093138267], [0.2, [0, 0, 0, 1, 75], -218.12260879618842], [0.0, [2, 0, 0, 0, 75], -157.56679164087834], [0.0, [2, 0, 0, 
# ...

# %%
# <pos> : {W, N, E, S, C}
# //
# <mat> : {0, 1, 2}
# //
# <arrow> : {0, 1, 2, 3}
# //
# <state> : {D, R}
# //
# <health> : {0,25,50,75,100}
# //
# <action> : {UP, LEFT, DOWN, RIGHT,
# NONE}
print(best_action['[3, 0, 0, 1, 25]'])
print(action_results['[3, 0, 0, 1, 25]'])
# Out:
# GATHER
# {'UP': [[0.425, [4, 0, 0, 1, 25], -129.05200128684857], [0.425, [4, 0, 0, 0, 25], -68.35160634559614], [0.075, [2, 0, 0, 1, 25], -105.32611624478994], [0.075, [2, 0, 0, 0, 25], -46.681285076476925]], 'STAY': [[0.425, [3, 0, 0, 1, 25], -90.36837459095719], [0.425, [3, 0, 0, 0, 25], -86.07541253150748], [0.075, [2, 0, 0, 1, 25], -105.32611624478994], [0.075, [2, 0, 0, 0, 25], -46.681285076476925]], 'GATHER': [[0.125, [3, 0, 0, 1, 25], -90.36837459095719], [0.125, [3, 0, 0, 0, 25], -86.07541253150748], [0.375, [3, 1, 0, 1, 25], -86.69211401785282], [0.375, [3, 1, 0, 0, 25], -69.02413463324997]]}

# %%
# action_frequency = {'UP': 92, 'LEFT': 6, 'DOWN': 39, 'RIGHT': 101,
#  'STAY': 68, 'SHOOT': 87, 'HIT': 39, 'CRAFT': 38, 'GATHER': 10, 'NONE': 120}

# action_frequency = {'UP': 46, 'LEFT': 130, 'DOWN': 27, 'RIGHT': 3, 'STAY': 198, 'SHOOT': 57, 'HIT': 7, 'CRAFT': 12, 'GATHER': 0, 'NONE': 120}
# action_frequency = {'UP': 33, 'LEFT': 45, 'DOWN': 49, 'RIGHT': 9, 'STAY': 45, 'SHOOT': 99, 'HIT': 93, 'CRAFT': 44, 'GATHER': 63, 'NONE': 120}
action_frequency = {'UP': 92, 'LEFT': 12, 'DOWN': 39, 'RIGHT': 101, 'STAY': 68, 'SHOOT': 84, 'HIT': 36, 'CRAFT': 38, 'GATHER': 10, 'NONE': 120}

x = action_frequency.keys()
y = action_frequency.values()

plt.figure(figsize=(10,5))

plt.title('Actions vs Frequency', fontweight="bold")
plt.xlabel('Actions', fontweight="bold")
plt.ylabel('Frequency', fontweight="bold")
plt.bar(x, y)
plt.show()
